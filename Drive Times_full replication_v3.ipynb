# %%
#Import Libraries
import requests
import pandas as pd
import numpy as np

key = "AIzaSyDlTMtfALAOij6dBzea0kGjjHAJe-1ZxJo" # STEVE KEY

# %%
def find_drivetime(location, address):
    distance, duration = None, None

    url = "https://maps.googleapis.com/maps/api/distancematrix/json?units=imperial&origins="+location+"&destinations="+address+"&units=imperial&departure_time=1711980000&key="+key
    payload={}
    headers = {}
    response = requests.request("GET", url, headers=headers, data=payload)
    if response.status_code not in range(200,299):
        return None, None

    try:
        results = response.json()
        distance = results['rows'][0]['elements'][0]['distance']['text']
        duration = results['rows'][0]['elements'][0]['duration_in_traffic']['value']

    except:
        pass

    return distance, duration

def add_drivetime_dataframe(row):
    row_num = str(row.name + 1)
    print(f"\rProgress: Row # "+row_num,end="")
    GPS_location = row['location']
    Hosp_Address = row['hospital_address']
    distance, duration = find_drivetime(GPS_location, Hosp_Address)
    row['distance'] = distance
    row['duration_seconds'] = duration
    return row

# %%
#Import population-weighted zip code centroid latitudes and longitudes
zips = pd.read_csv(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Zip_Code_Population_Weighted_Centroids.csv')
zips['STD_ZIP5'] = zips['STD_ZIP5'].astype(int)

#Import desired hospital - zip code pairs 
Pairs = pd.read_stata(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\15 Creating Combined Inpatient Choice Model Data\\Intermediate\\location pairs for drive times filtered.dta')
Pairs['patient_zip'] = Pairs['patient_zip'].astype(int)

#Merge Together
Pairs = Pairs.merge(zips, left_on='patient_zip', right_on='STD_ZIP5')
Pairs['location'] = Pairs['LATITUDE'].astype(str) + '%2C' + Pairs['LONGITUDE'].astype(str)
Pairs = Pairs[['patient_zip','hospital_id','hospital_address','adr_label','location']]

#Split into chunks
number_of_chunks = 120
df_split = np.array_split(Pairs, number_of_chunks)
del Pairs

#Request Drive Times and Save for each chunk
for i in range(0,number_of_chunks):
    #Request Drive Times
    df_split[i] = df_split[i].apply(add_drivetime_dataframe, axis=1)

    #destring distance
    df_split[i]['drive_miles'] = df_split[i]['distance'].str.extract(r'(\d+)').astype(int)

    #Save with all fields to intermediate folder
    chunk_num = i + 1
    df_split[i].to_csv(r'\\na2-fs1\DCDATA6\\Cases\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\CSV\\Chunk '+str(chunk_num)+'.csv', index = False)
    df_split[i].to_stata(r'\\na2-fs1\DCDATA6\\Cases\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\DTA\\Chunk '+str(chunk_num)+'.dta', write_index = False)

    #Keep columns of interest for Analysis Data
    df_split[i] = df_split[i][['patient_zip','hospital_id','hospital_address','adr_label','duration_seconds','drive_miles']]

    #Update user 
    print(" | Finished "+str(i+1)+" of "+str(number_of_chunks)+" chunks")

#Append chunks and save as analysis version
df = pd.read_csv(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\CSV\\Chunk 1.csv')
for i in range (2,number_of_chunks+1):
    df_add = pd.read_csv(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\CSV\\Chunk '+str(i)+'.csv')
    df = pd.concat([df,df_add],ignore_index=True) 

#Save as Analysis Version
df.to_csv(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\10 BRG Expert Reports\\2023.09.01 Meer Expert Report\\01 Preproduction\\01 Data\\04 Google Drivetimes\\Drive Times.csv', index = False)
df.to_stata(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\10 BRG Expert Reports\\2023.09.01 Meer Expert Report\\01 Preproduction\\01 Data\\04 Google Drivetimes\\Drive Times.dta', write_index = False)

# %% [markdown]
# SECOND PASS | Completed until Chunk 107 | Starting Re-run with Chunk 108

# %%
#Import population-weighted zip code centroid latitudes and longitudes
zips = pd.read_csv(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Zip_Code_Population_Weighted_Centroids.csv')
zips['STD_ZIP5'] = zips['STD_ZIP5'].astype(int)

#Import desired hospital - zip code pairs 
Pairs = pd.read_stata(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\15 Creating Combined Inpatient Choice Model Data\\Intermediate\\location pairs for drive times filtered.dta')
Pairs['patient_zip'] = Pairs['patient_zip'].astype(int)

#Merge Together
Pairs = Pairs.merge(zips, left_on='patient_zip', right_on='STD_ZIP5')
Pairs['location'] = Pairs['LATITUDE'].astype(str) + '%2C' + Pairs['LONGITUDE'].astype(str)
Pairs = Pairs[['patient_zip','hospital_id','hospital_address','adr_label','location']]

#Split into chunks
number_of_chunks = 120
df_split = np.array_split(Pairs, number_of_chunks)
del Pairs

#Request Drive Times and Save for each chunk
for i in range(107,number_of_chunks):
    #Request Drive Times
    df_split[i] = df_split[i].apply(add_drivetime_dataframe, axis=1)

    #destring distance
    df_split[i]['drive_miles'] = df_split[i]['distance'].str.extract(r'(\d+)').astype(int)

    #Save with all fields to intermediate folder
    chunk_num = i + 1
    df_split[i].to_csv(r'\\na2-fs1\DCDATA6\\Cases\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\CSV\\Chunk '+str(chunk_num)+'.csv', index = False)
    df_split[i].to_stata(r'\\na2-fs1\DCDATA6\\Cases\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\DTA\\Chunk '+str(chunk_num)+'.dta', write_index = False)

    #Keep columns of interest for Analysis Data
    df_split[i] = df_split[i][['patient_zip','hospital_id','hospital_address','adr_label','duration_seconds','drive_miles']]

    #Update user 
    print(" | Finished "+str(i+1)+" of "+str(number_of_chunks)+" chunks")

#Append chunks and save as analysis version
df = pd.read_csv(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\CSV\\Chunk 1.csv')
for i in range (2,number_of_chunks+1):
    df_add = pd.read_csv(r'\\na2-fs1\\DCDATA6\\Cases\\Active\\Dr. Vasquez . IU Health (047898)\\08 Work Product\\36 Drive Times\\Intermediate\\Chunks from Minutes Version\\CSV\\Chunk '+str(i)+'.csv')
    df = pd.concat([df,df_add],ignore_index=True) 

#Save as Analysis Version
df.to_csv(r'\\na2-fs1\DCDATA6\\Cases\Active\\Dr. Vasquez . IU Health (047898)\\10 BRG Expert Reports\\2023.09.01 Meer Expert Report\\01 Preproduction\\01 Data\\04 Google Drivetimes\\Drive Times.csv', index = False)
df.to_stata(r'\\na2-fs1\DCDATA6\\Cases\Active\\Dr. Vasquez . IU Health (047898)\\10 BRG Expert Reports\\2023.09.01 Meer Expert Report\\01 Preproduction\\01 Data\\04 Google Drivetimes\\Drive Times.dta', write_index = False)
