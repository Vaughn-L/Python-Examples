# %% [markdown]
# ## SOURCE: IMAGES

# %%
from PIL import Image
import pytesseract
import tabula
from tabula import read_pdf
import re 
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract\tesseract.exe'
import fitz
import PIL.Image
import io

# %% [markdown]
# ---

# %% [markdown]
# ## SOURCE: PDF

# %% [markdown]
# Text

# %%
text = extract_text(r'C:\Users\Matthew.Vaughn\OneDrive - Berkeley Research Group, LLC\Python Code Examples\PDFs and Images\Test Data\Fake Table .pdf')
pattern = re.compile(r'[a-zA-Z]+\s{1}')
matches = pattern.findall(text)
First_Matches = [n[:-2] for n in matches]
print(matches)
print(First_Matches)

# %% [markdown]
# Images

# %%
pdf = fitz.open(r'C:\Users\Matthew.Vaughn\OneDrive - Berkeley Research Group, LLC\Python Code Examples\PDFs and Images\Test Data\Andrew Graham Beshear.pdf')
counter = 1 
for i in range(len(pdf)):
    page = pdf[i]
    images=page.get_images()
    for image in images:
        base_img = pdf.extract_image(image[0])
        image_data = base_img["image"]
        img = PIL.Image.open(io.BytesIO(image_data))
        extension = base_img["ext"]
        img.save(open(f"image{counter}.{extension}", "wb"))
        counter += 1

# %% [markdown]
# Tables

# %%
tables = tabula.read_pdf(r'C:\Users\Matthew.Vaughn\OneDrive - Berkeley Research Group, LLC\053003 Toll House\Veronica Silva Time Records 2022.pdf', pages='all')

# %%
#From 0 to len(tables), export each table to a csv file
for i in range(len(tables)):
    tables[i].to_csv(rf'C:\Users\Matthew.Vaughn\OneDrive - Berkeley Research Group, LLC\053003 Toll House\Veronica Silva Time Records 2022_table_{i}.csv', index=False)

# %%
tables[0].to_csv(r'C:\Users\Matthew.Vaughn\OneDrive - Berkeley Research Group, LLC\Python Code Examples\PDFs and Images\Test Data\formatt.csv', index=False)
